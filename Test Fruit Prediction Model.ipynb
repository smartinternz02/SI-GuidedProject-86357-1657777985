# %%
train_dir=r'C:\Users\Abirami\Desktop\old_smartinternz\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset\train'
test_dir=r'C:\Users\Abirami\Desktop\old_smartinternz\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset\test'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Load the model

# %%
model = tf.keras.models.load_model(r'C:\Users\Abirami\Desktop\smartinternz\fruit.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 1686 images belonging to 6 classes.

# %% [markdown]
# # Evaluate

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"C:\Users\Abirami\Desktop\old_smartinternz\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset\test\Apple___Black_rot\00e909aa-e3ae-4558-9961-336bb0f35db3___JR_FrgE.S 8593.JPG")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x23C74C15F88>

# %%
img=image.load_img(r"C:\Users\Abirami\Desktop\old_smartinternz\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset\test\Apple___Black_rot\00e909aa-e3ae-4558-9961-336bb0f35db3___JR_FrgE.S 8593.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 'Apple___Black_rot'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 6s 120ms/step - loss: 0.2565 - accuracy: 0.9480
# [0.2564503252506256, 0.9480000138282776]
